# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn import metrics

# %%
data = pd.read_csv("lung cancer data.csv")
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data['GENDER'] = data['GENDER'].map({'M':1, 'F':2})
data
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         1   69        1               2        2              1
# 1         1   74        2               1        1              1
# 2         2   59        1               1        1              2
# 3         1   63        2               2        2              1
# 4         2   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       2   56        1               1        1              2
# 305       1   70        2               1        1              1
# 306       1   58        2               1        1              1
# 307       1   67        2               1        2              1
# 308       1   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
plt.figure(figsize=(8,10) , dpi=70)
plt.scatter(data.LUNG_CANCER,data.AGE)
plt.xlabel('lung cancer')
plt.ylabel('age')
plt.show()

# %%
data.corr()
# Out:
#                          GENDER       AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# GENDER                 1.000000 -0.021306 -0.036277        0.212959  0.152127
# AGE                   -0.021306  1.000000 -0.084475        0.005205  0.053170
# SMOKING               -0.036277 -0.084475  1.000000       -0.014585  0.160267
# YELLOW_FINGERS         0.212959  0.005205 -0.014585        1.000000  0.565829
# ANXIETY                0.152127  0.053170  0.160267        0.565829  1.000000
# PEER_PRESSURE          0.275564  0.018685 -0.042822        0.323083  0.216841
# CHRONIC DISEASE        0.204606 -0.012642 -0.141522        0.041122 -0.009678
# FATIGUE                0.083560  0.012614 -0.029575       -0.118058 -0.188538
# ALLERGY               -0.154251  0.027990  0.001913       -0.144300 -0.165750
# WHEEZING              -0.141207  0.055011 -0.129426       -0.078515 -0.191807
# ALCOHOL CONSUMING     -0.454268  0.058985 -0.050623       -0.289025 -0.165750
# ...

# %%
sns.countplot(x='LUNG_CANCER',data=data)
# Out:
# <AxesSubplot:xlabel='LUNG_CANCER', ylabel='count'>

# %%
x_data  = data.drop('LUNG_CANCER', axis=1)
y_data = data[['LUNG_CANCER']]

model = LogisticRegression()
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

# %%
results = cross_val_score(model, x_data, y_data, cv=10)
print(results.mean())
print(results)
# Out:
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 0.9032258064516129
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fpr,tpr,_ = metrics.roc_curve(y_test,y_pred)
plt.plot(fpr,tpr,color= "orange")
plt.show()

# %%
y_pred_proba = model.predict_proba(x_test)[::,1]
fpr,tpr,_ = metrics.roc_curve(y_test, y_pred_proba)
auc = metrics.roc_auc_score(y_test,y_pred_proba)
plt.plot(fpr,tpr,color="red", label="auc: "+str(auc))
plt.legend(loc=4)

# %%
print(metrics.classification_report(y_data,model.predict(x_data)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.56      0.66        39
#            1       0.94      0.98      0.96       270
#
#     accuracy                           0.93       309
#    macro avg       0.86      0.77      0.81       309
# weighted avg       0.92      0.93      0.92       309

# %%
print(metrics.confusion_matrix(y_data,model.predict(x_data)))
# Out:
# [[ 22  17]
#  [  6 264]]

# %%
classifier1 = MultinomialNB()
classifier1.fit(x_train, y_train)
classifier1.predict(x_test)
cm = metrics.confusion_matrix( classifier1.predict(x_test),y_test)
print(cm)
print(metrics.classification_report(y_pred, y_test))
# Out:
# [[ 0  0]
#  [10 52]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.83      0.62         6
#            1       0.98      0.91      0.94        56
#
#     accuracy                           0.90        62
#    macro avg       0.74      0.87      0.78        62
# weighted avg       0.93      0.90      0.91        62
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
sns.heatmap(cm, annot= True, xticklabels=["Lung cancer","Not Long cancer"], yticklabels=["Lung cancer","Not Long cancer"])
plt.show()

# %%
x = data.drop("LUNG_CANCER",axis=1)
x = x.drop("AGE", axis=1)
y = data[["LUNG_CANCER"]]

# %%
classifier2 = BernoulliNB()
classifier2.fit(x,y)
conmx = metrics.confusion_matrix(classifier2.predict(x),y)
print("confusion matrix: ",conmx)
# Out:
# confusion matrix:  [[  0   0]
#  [ 39 270]]
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
